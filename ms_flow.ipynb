# %%
from automate.eserv import config_factory

config = config_factory()

ms_cred = config.credentials['microsoft-outlook']
ms_cred.manager.acquire_token()

config.credentials.persist()
# Out:
# 2025-12-08T02:48:52.798057 [info     ] Configuration loaded           cache_ttl=4 dotenv_path= [info     ] Configuration loaded           cache_ttl=4 dotenv_path=None service_dir=C:\Users\mythb\source\automate\.service smtp_server=smtp.gmail.com
